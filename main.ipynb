# %%
from bs4 import BeautifulSoup
import requests

# %%
# BeatifulSoup dan Requests (1)
url = requests.get('http://www.scrapethissite.com/pages/forms/?per_page=100')
# print(url.text)
# print(url.content)

soup = BeautifulSoup(url.text, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping</title>
# <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# <link href="/static/css/styles.css" rel="stylesheet" type="text/css"/>
# ...

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping\n  </title>\n  <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>\n  <meta content="width=device-width, initial-scale=1.0" name="viewport"/>\n  <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>\n  <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>\n  <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>\n  <link href="/static/css/styles.css" rel="stylesheet" type="text/css
# ...

# %%
# print(soup.prettify())

# %%
# Inspecting Web Pages with HTML / Memeriksa Halaman Web dengan HTML
# Find and Find_All
# navs = soup.find_all('ul', {'class' : 'nav nav-tabs'})
navs = soup.find_all('li')
# navs
# for nav in navs:
    # print(nav['src'])
    # Berdasarkan Img
    # for item in nav.find_all('img'):
    #     print(f"img : {item['src']}")
    # Berdasarkan li
    # for item in nav.find_all('li'):
    #     print(f"{item.get_text()}")
   # pass

# %%
# Kita ambil ke menu Search
teams = soup.find_all('tr', class_='team')[0]
len(teams)
print()

# %%
# karena kalo error dengan text ini karna find all ini tidak memiliki text
# soup.find_all('p', class_='lead').text
h1 = soup.find('h1').get_text().replace('\n', '') #.replace(' ', '') # .split()
h1
# Out:
# '                            Hockey Teams: Forms, Searching and Pagination                            100 items'

# %%
# berbeda dengan fungsi find yg memiliki text
p = soup.find('p', class_='lead').get_text().replace('\n', '') #.replace(' ', '')
p
# Out:
# '                            Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components.                            Take a look at how pagination and search elements change the URL as your browse. Build a web scraper that can conduct searches and paginate through the results.                        '

# %%
rows = soup.find_all('div', {'class' : 'row'})[2]
for row in rows.find_all('p'):
    print(row.get_text())
    # if row.find_all('p') == [0]:
    #     print(row.get_text())
    # elif row.find_all('p') == [1]:
    #     print(row.get_text())
# row.text
# Out:
#  There are 8 video lessons that show you how to scrape this page.
#
#
#
#                                 Data via
#                                 http://www.opensourcesports.com/hockey/

# %%
table   = soup.find_all('table', {'class' : 'table'})[0]
# table
rows    = table.find_all('tr')
# rows
for row in rows:
    # print(row.get_text())
    for item in row.find_all(['td', 'th']):
        print(item.get_text())
# Out:
#                             Team Name
#
#
#                             Year
#
#
#                             Wins
#
#
#                             Losses
#
#
#                             OT Losses
#
#
#                             Win %
#
#
#                             Goals For (GF)
#
#
#                             Goals Against (GA)
#
#
#                             + / -
#
#
#                             Boston Bruins
#
#
#                             1990
#
#
#                             44
#
#
#                             24
#
#
#
#
#                             0.55
#
#
#                             299
#
#
#                             264
#
#
#                             35
#
#
#                             Buffalo Sabres
#
#
#                             1990
#
#
#                             31
#
#
#                             30
#
#
#
#
#                             0.388
#
#
#                             292
#
#
#                             278
#
#
# ...

# %%
hasil = []
for row in rows:
    info = []
    for item in row.find_all(['td', 'th']):
        # print(item.get_text())
        info.append(item.text
                    .replace('\n                            ', '')
                    .replace('\n                        ', ''))
    hasil.append(info)
print(hasil)
# Out:
# [['Team Name', 'Year', 'Wins', 'Losses', 'OT Losses', 'Win %', 'Goals For (GF)', 'Goals Against (GA)', '+ / -'], ['Boston Bruins', '1990', '44', '24', '\n', '0.55', '299', '264', '35'], ['Buffalo Sabres', '1990', '31', '30', '\n', '0.388', '292', '278', '14'], ['Calgary Flames', '1990', '46', '26', '\n', '0.575', '344', '263', '81'], ['Chicago Blackhawks', '1990', '49', '23', '\n', '0.613', '284', '211', '73'], ['Detroit Red Wings', '1990', '34', '38', '\n', '0.425', '273', '298', '-25'], ['Edmonton Oilers', '1990', '37', '37', '\n', '0.463', '272', '272', '0'], ['Hartford Whalers', '1990', '31', '38', '\n', '0.388', '238', '276', '-38'], ['Los Angeles Kings', '1990', '46', '24', '\n', '0.575', '340', '254', '86'], ['Minnesota North Stars', '1990', '27', '39', '\n', '0.338', '256', '266', '-10'], ['Montreal Canadiens', '1990', '39', '30', '\n', '0.487', '273', '249', '24'], ['New Jersey Devils', '1990', '32', '33', '\n', '0.4', '272', '264', '8'], ['New York Islanders', '1990', '25',
# ...

# %%
import pandas as pd
df = pd.DataFrame(hasil) # Convert list kedalam DataFrame
new_header = df.iloc[0]
df = df[1:]
df.columns = new_header # mengubah first row menjadi column header
df.reset_index(drop=True, inplace=True) #reset index sehingga dimulai dari 0
display(df)
# Out:
# 0            Team Name  Year Wins Losses OT Losses  Win % Goals For (GF)  \
# 0        Boston Bruins  1990   44     24        \n   0.55            299
# 1       Buffalo Sabres  1990   31     30        \n  0.388            292
# 2       Calgary Flames  1990   46     26        \n  0.575            344
# 3   Chicago Blackhawks  1990   49     23        \n  0.613            284
# 4    Detroit Red Wings  1990   34     38        \n  0.425            273
# ..                 ...   ...  ...    ...       ...    ...            ...
# 95      Buffalo Sabres  1994   22     19        \n  0.458            130
# 96      Calgary Flames  1994   24     17        \n    0.5            163
# 97  Chicago Blackhawks  1994   24     19        \n    0.5            156
# 98        Dallas Stars  1994   17     23        \n  0.354            136
# 99   Detroit Red Wings  1994   33     11        \n  0.688            180
#
# 0  Goals Against (GA) + / -
# 0                 264    35
# 1                 278    14
# ...

# %%
df.to_csv('hockeyTeam.csv')
df.to_excel('hockeyTeam.xlsx', sheet_name='hockeyTeam')
df.to_json('hockeyTeam.json')

# %%
# MULTIPLE PAGES (PAGINATION)
url = 'https://www.scrapethissite.com/pages/forms/?page_num=1&per_page=100'

# ditahap ini kita akan menyatukan beberapa halaman
# Cara 1
# for i in range(1, 50):
#     urls = 'https://www.scrapethissite.com/pages/forms/?page_num={}&per_page=100'.format(i)
# print(urls)

# Cara 2
urls = ['https://www.scrapethissite.com/pages/forms/?page_num={}&per_page=100'.format(i) for i in range(1, 7)]
urls
# Out:
# ['https://www.scrapethissite.com/pages/forms/?page_num=1&per_page=100',
#  'https://www.scrapethissite.com/pages/forms/?page_num=2&per_page=100',
#  'https://www.scrapethissite.com/pages/forms/?page_num=3&per_page=100',
#  'https://www.scrapethissite.com/pages/forms/?page_num=4&per_page=100',
#  'https://www.scrapethissite.com/pages/forms/?page_num=5&per_page=100',
#  'https://www.scrapethissite.com/pages/forms/?page_num=6&per_page=100']
